# %% [markdown]
# # Задание 2.2 - Введение в PyTorch
#
# Для этого задания потребуется установить версию PyTorch 1.0
#
# https://pytorch.org/get-started/locally/
#
# В этом задании мы познакомимся с основными компонентами PyTorch и натренируем несколько небольших моделей.<br>
# GPU нам пока не понадобится.
#
# Основные ссылки:
# https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html
# https://pytorch.org/docs/stable/nn.html
# https://pytorch.org/docs/stable/torchvision/index.html

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as dset
from torch.utils.data.sampler import SubsetRandomSampler, Sampler
from torch.optim.lr_scheduler import StepLR
from torchvision import transforms

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# %% [markdown]
# ## Как всегда, начинаем с загрузки данных
#
# PyTorch поддерживает загрузку SVHN из коробки.

# %%
# First, lets load the dataset
data_train = dset.SVHN('./data/', split='train',
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize(mean=[0.43,0.44,0.47],
                                               std=[0.20,0.20,0.20])                           
                       ])
                      )
data_test = dset.SVHN('./data/', split='test', 
                      transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize(mean=[0.43,0.44,0.47],
                                               std=[0.20,0.20,0.20])                           
                       ]))

# %% [markdown]
# Теперь мы разделим данные на training и validation с использованием классов `SubsetRandomSampler` и `DataLoader`.
#
# `DataLoader` подгружает данные, предоставляемые классом `Dataset`, во время тренировки и группирует их в батчи.
# Он дает возможность указать `Sampler`, который выбирает, какие примеры из датасета использовать для тренировки. Мы используем это, чтобы разделить данные на training и validation.
#
# Подробнее: https://pytorch.org/tutorials/beginner/data_loading_tutorial.html

# %%
batch_size = 64

data_size = data_train.data.shape[0]
validation_split = .2
split = int(np.floor(validation_split * data_size))
indices = list(range(data_size))
np.random.shuffle(indices)

train_indices, val_indices = indices[split:], indices[:split]

train_sampler = SubsetRandomSampler(train_indices)
val_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(data_train, batch_size=batch_size, 
                                           sampler=train_sampler)
val_loader = torch.utils.data.DataLoader(data_train, batch_size=batch_size,
                                         sampler=val_sampler)

# %% [markdown]
# В нашей задаче мы получаем на вход изображения, но работаем с ними как с одномерными массивами. Чтобы превратить многомерный массив в одномерный, мы воспользуемся очень простым вспомогательным модулем `Flattener`.

# %%
sample, label = data_train[0]
print("SVHN data sample shape: ", sample.shape)
# As you can see, the data is shaped like an image

# We'll use a special helper module to shape it into a tensor
class Flattener(nn.Module):
    def forward(self, x):
        batch_size, *_ = x.shape
        return x.view(batch_size, -1)
# Out:
# SVHN data sample shape:  torch.Size([3, 32, 32])

# %% [markdown]
# И наконец, мы создаем основные объекты PyTorch:
# - `nn_model` - собственно, модель с нейросетью
# - `loss` - функцию ошибки, в нашем случае `CrossEntropyLoss`
# - `optimizer` - алгоритм оптимизации, в нашем случае просто `SGD`

# %%
nn_model = nn.Sequential(
            Flattener(),
            nn.Linear(3*32*32, 100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 10), 
         )
nn_model.type(torch.FloatTensor)

# We will minimize cross-entropy between the ground truth and
# network predictions using an SGD optimizer
loss = nn.CrossEntropyLoss().type(torch.FloatTensor)
optimizer = optim.SGD(nn_model.parameters(), lr=1e-2, weight_decay=1e-1)

# %% [markdown]
# ## Тренируем!
#
# Ниже приведена функция `train_model`, реализующая основной цикл тренировки PyTorch.
#
# Каждую эпоху эта функция вызывает функцию `compute_accuracy`, которая вычисляет точность на validation, эту последнюю функцию предлагается реализовать вам.

# %%
# This is how to implement the same main train loop in PyTorch. Pretty easy, right?

def train_model(model, train_loader, val_loader, loss, 
                optimizer, num_epochs, enable_scheduler=False, 
                scheduler_sz=2, scheduler_gamma=0.5):    
    loss_history = []
    train_history = []
    val_history = []
    
    if enable_scheduler is True:
    # added learning rate decay scheduler
        scheduler = StepLR(optimizer, step_size=scheduler_sz, gamma=scheduler_gamma)
    
    for epoch in range(num_epochs):
        model.train() # Enter train mode
        
        loss_accum = 0
        correct_samples = 0
        total_samples = 0
        for i_step, (x, y) in enumerate(train_loader):
            prediction = model(x)    
            loss_value = loss(prediction, y)
            optimizer.zero_grad()
            loss_value.backward()
            optimizer.step()
            
            _, indices = torch.max(prediction, 1)
            correct_samples += torch.sum(indices == y)
            total_samples += y.shape[0]
            
            loss_accum += loss_value

        ave_loss = loss_accum / (i_step + 1)
        train_accuracy = float(correct_samples) / total_samples
        val_accuracy = compute_accuracy(model, val_loader)
        
        loss_history.append(float(ave_loss))
        train_history.append(train_accuracy)
        val_history.append(val_accuracy)
        
        if enable_scheduler is True:
            scheduler.step()
        
        print("Average loss: %f, Train accuracy: %f, Val accuracy: %f" % (ave_loss, train_accuracy, val_accuracy))
        
    return loss_history, train_history, val_history
        
def compute_accuracy(model, loader):
    """
    Computes accuracy on the dataset wrapped in a loader
    
    Returns: accuracy as a float value between 0 and 1
    """
    
    model.eval() # Evaluation mode
    # TODO: Implement the inference of the model on all of the batches from loader,
    #       and compute the overall accuracy.
    # Hint: PyTorch has the argmax function!
    correct = 0
    total = 0
    
    for data in val_loader:
        x, y = data
        predictions = model(x)
        _, predicted = torch.max(predictions.data, 1)
        correct += torch.sum(predicted == y)
        total += y.shape[0]
    total_accuracy = correct/total
    return total_accuracy

loss_history, train_history, val_history = train_model(nn_model, train_loader, val_loader, loss, optimizer, 3)

# %% [markdown]
# ## После основного цикла
#
# Посмотрим на другие возможности и оптимизации, которые предоставляет PyTorch.
#
# Добавьте еще один скрытый слой размера 100 нейронов к модели

# %%
# Since it's so easy to add layers, let's add some!

# TODO: Implement a model with 2 hidden layers of the size 100
nn_model = nn.Sequential(
            Flattener(),
            nn.Linear(3*32*32, 100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 100), 
            nn.ReLU(inplace=True),
            nn.Linear(100, 10),
       )
nn_model.type(torch.FloatTensor)

optimizer = optim.SGD(nn_model.parameters(), lr=1e-2, weight_decay=1e-1)
loss_history, train_history, val_history = train_model(nn_model, train_loader, val_loader, loss, optimizer, 5)
# Out:
# Average loss: 2.187934, Train accuracy: 0.204382, Val accuracy: 0.217187
# Average loss: 2.029988, Train accuracy: 0.258250, Val accuracy: 0.298068
# Average loss: 1.834744, Train accuracy: 0.361687, Val accuracy: 0.408163
# Average loss: 1.707930, Train accuracy: 0.422687, Val accuracy: 0.415125
# Average loss: 1.676869, Train accuracy: 0.438846, Val accuracy: 0.443110

# %% [markdown]
# Добавьте слой с Batch Normalization

# %%
# We heard batch normalization is powerful, let's use it!
# TODO: Add batch normalization after each of the hidden layers of the network, before or after non-linearity
# Hint: check out torch.nn.BatchNorm1d

nn_model = nn.Sequential(
            Flattener(),
            nn.Linear(3*32*32, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 100), 
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 10),
       )

optimizer = optim.SGD(nn_model.parameters(), lr=1e-3, weight_decay=1e-1)
loss_history, train_history, val_history = train_model(nn_model, train_loader, val_loader, loss, optimizer, 5)
# Out:
# Average loss: 2.043429, Train accuracy: 0.316708, Val accuracy: 0.438673
# Average loss: 1.750958, Train accuracy: 0.479968, Val accuracy: 0.521876
# Average loss: 1.618957, Train accuracy: 0.546343, Val accuracy: 0.579619
# Average loss: 1.534422, Train accuracy: 0.589632, Val accuracy: 0.601734
# Average loss: 1.471849, Train accuracy: 0.618930, Val accuracy: 0.633404

# %% [markdown]
# Добавьте уменьшение скорости обучения по ходу тренировки.

# %%
# Learning rate annealing
# Reduce your learning rate 2x every 2 epochs
# Hint: look up learning rate schedulers in PyTorch. You might need to extend train_model function a little bit too!

nn_model = nn.Sequential(
            Flattener(),
            nn.Linear(3*32*32, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 100), 
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 10),
       )
         

optimizer = optim.SGD(nn_model.parameters(), lr=1e-3, weight_decay=1e-1)
loss_history, train_history, val_history =\
train_model(nn_model, train_loader, val_loader, loss, optimizer, 5,enable_scheduler=True, scheduler_gamma=0.2)
# Out:
# Average loss: 2.031829, Train accuracy: 0.319865, Val accuracy: 0.457170
# Average loss: 1.720293, Train accuracy: 0.496024, Val accuracy: 0.545424
# Average loss: 1.618288, Train accuracy: 0.545524, Val accuracy: 0.559894
# Average loss: 1.594479, Train accuracy: 0.557417, Val accuracy: 0.574227
# Average loss: 1.578704, Train accuracy: 0.564157, Val accuracy: 0.579141

# %% [markdown]
# # Визуализируем ошибки модели
#
# Попробуем посмотреть, на каких изображениях наша модель ошибается.
# Для этого мы получим все предсказания модели на validation set и сравним их с истинными метками (ground truth).
#
# Первая часть - реализовать код на PyTorch, который вычисляет все предсказания модели на validation set.
# Чтобы это сделать мы приводим код `SubsetSampler`, который просто проходит по всем заданным индексам последовательно и составляет из них батчи.
#
# Реализуйте функцию `evaluate_model`, которая прогоняет модель через все сэмплы validation set и запоминает предсказания модели и истинные метки.

# %%
class SubsetSampler(Sampler):
    r"""Samples elements with given indices sequentially

    Arguments:
        indices (ndarray): indices of the samples to take
    """

    def __init__(self, indices):
        self.indices = indices

    def __iter__(self):
        return (self.indices[i] for i in range(len(self.indices)))

    def __len__(self):
        return len(self.indices)
    
    
def evaluate_model(model, dataset, indices):
    """
    Computes predictions and ground truth labels for the indices of the dataset
    
    Returns: 
    predictions: np array of ints - model predictions
    grount_truth: np array of ints - actual labels of the dataset
    """
    model.eval() # Evaluation mode
    
    # TODO: Evaluate model on the list of indices and capture predictions
    # and ground truth labels
    # Hint: SubsetSampler above could be useful!
    
    val_sampler = SubsetSampler(indices)
    val_loader = torch.utils.data.DataLoader(dataset,
                                             sampler=val_sampler, shuffle=False)
    
    predictions = np.array([])
    ground_truth = np.array([])    
    ys = []
    for data in val_loader:
        x, y = data
        prediction = model(x)
        _, predicted = torch.max(prediction.data, 1)
        predictions = np.append(predictions, predicted)
        ground_truth = np.append(ground_truth, y)
        ys.append(y)
    return predictions, ground_truth, ys

# Evaluate model on validation
predictions, gt, ys = evaluate_model(nn_model, data_train, val_indices)
assert len(predictions) == len(val_indices)
assert len(gt) == len(val_indices)
assert gt[100] == data_train[val_indices[100]][1]
assert np.any(np.not_equal(gt, predictions))

# %% [markdown]
# ## Confusion matrix
# Первая часть визуализации - вывести confusion matrix (https://en.wikipedia.org/wiki/Confusion_matrix ).
#
# Confusion matrix - это матрица, где каждой строке соответствуют классы предсказанный, а столбцу - классы истинных меток (ground truth). Число с координатами `i,j` - это количество сэмплов класса `j`, которые модель считает классом `i`.
#
# ![image.png](attachment:image.png)
#
# Для того, чтобы облегчить вам задачу, ниже реализована функция `visualize_confusion_matrix` которая визуализирует такую матрицу.
# Вам осталось реализовать функцию `build_confusion_matrix`, которая ее вычислит.
#
# Результатом должна быть матрица 10x10.

# %%
def visualize_confusion_matrix(confusion_matrix):
    """
    Visualizes confusion matrix
    
    confusion_matrix: np array of ints, x axis - predicted class, y axis - actual class
                      [i][j] should have the count of samples that were predicted to be class i,
                      but have j in the ground truth
                     
    """
    # Adapted from 
    # https://stackoverflow.com/questions/2897826/confusion-matrix-with-number-of-classified-misclassified-instances-on-it-python
    assert confusion_matrix.shape[0] == confusion_matrix.shape[1]
    size = confusion_matrix.shape[0]
    fig = plt.figure(figsize=(10,10))
    plt.title("Confusion matrix")
    plt.ylabel("predicted")
    plt.xlabel("ground truth")
    res = plt.imshow(confusion_matrix, cmap='GnBu', interpolation='nearest')
    cb = fig.colorbar(res)
    plt.xticks(np.arange(size))
    plt.yticks(np.arange(size))
    for i, row in enumerate(confusion_matrix):
        for j, count in enumerate(row):
            plt.text(j, i, count, fontsize=14, horizontalalignment='center', verticalalignment='center')
    
def build_confusion_matrix(predictions, ground_truth):
    """
    Builds confusion matrix from predictions and ground truth

    predictions: np array of ints, model predictions for all validation samples
    ground_truth: np array of ints, ground truth for all validation samples
    
    Returns:
    np array of ints, (10,10), counts of samples for predicted/ground_truth classes
    """
    
    confusion_matrix = np.zeros((10,10), int)
    
    # TODO: Implement filling the prediction matrix
    
    for i in range(len(confusion_matrix)):
        target_predictions = np.where(predictions == i)[0] # prediction indices equil to gt
        for x in range(len(confusion_matrix[0])):
            target = x # gt value
            predictions_count = 0

            for index in target_predictions:
                if ground_truth[index] == target:
                    predictions_count += 1

            confusion_matrix[i][x] = predictions_count
    
    return confusion_matrix

confusion_matrix = build_confusion_matrix(predictions, gt)
visualize_confusion_matrix(confusion_matrix)

# %% [markdown]
# Наконец, посмотрим на изображения, соответствующие некоторым элементам этой матрицы.
#
# Как и раньше, вам дана функция `visualize_images`, которой нужно воспрользоваться при реализации функции `visualize_predicted_actual`. Эта функция должна вывести несколько примеров, соответствующих заданному элементу матрицы.
#
# Визуализируйте наиболее частые ошибки и попробуйте понять, почему модель их совершает.

# %%
data_train_images = dset.SVHN('./data/', split='train')

def visualize_images(indices, data, title='', max_num=10):
    """
    Visualizes several images from the dataset
 
    indices: array of indices to visualize
    data: torch Dataset with the images
    title: string, title of the plot
    max_num: int, max number of images to display
    """
    to_show = min(len(indices), max_num)
    fig = plt.figure(figsize=(10,1.5))
    fig.suptitle(title)
    for i, index in enumerate(indices[:to_show]):
        plt.subplot(1,to_show, i+1)
        plt.axis('off')
        sample = data[index][0]
        plt.imshow(sample)
        
def visualize_predicted_actual(predicted_class, gt_class, predictions, groud_truth, val_indices, data):
    """
    Visualizes images of a ground truth class which were predicted as the other class 
    
    predicted: int 0-9, index of the predicted class
    gt_class: int 0-9, index of the ground truth class
    predictions: np array of ints, model predictions for all validation samples
    ground_truth: np array of ints, ground truth for all validation samples
    val_indices: np array of ints, indices of validation samples
    """
    
    # TODO: Implement visualization using visualize_images above
    # predictions and ground_truth are provided for validation set only, defined by val_indices
    # Hint: numpy index arrays might be helpful
    # https://docs.scipy.org/doc/numpy/user/basics.indexing.html#index-arrays
    # Please make the title meaningful!
    
    predicted_indices = np.where(predictions==predicted_class)[0]
    
    wrong_prediction_indices = np.where(groud_truth[predicted_indices]==gt_class)[0]
    wrong_prediction_val_indices = val_indices[wrong_prediction_indices]
    
    title = 'Ground truth is {g}, prediction is {p}'.format(g=gt_class, p=predicted_class)
    visualize_images(wrong_prediction_val_indices, data_train_images, title=title)

visualize_predicted_actual(6, 0, predictions, gt, np.array(val_indices), data_train_images)
visualize_predicted_actual(4, 5, predictions, gt, np.array(val_indices), data_train_images)

# %% [markdown]
# # Переходим к свободным упражнениям!
#
# Натренируйте модель как можно лучше - экспериментируйте сами!
# Что следует обязательно попробовать:
# - перебор гиперпараметров с помощью валидационной выборки
# - другие оптимизаторы вместо SGD
# - изменение количества слоев и их размеров
# - наличие Batch Normalization
#
# Но ограничиваться этим не стоит!
#
# Точность на тестовой выборке должна быть доведена до **80%**

# %%
# Experiment here!

# %%
nn_model = nn.Sequential(
            Flattener(),
            nn.Linear(3*32*32, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 50), 
            nn.BatchNorm1d(50),
            nn.ReLU(inplace=True),
            nn.Linear(50, 25), 
            nn.BatchNorm1d(25),
            nn.ReLU(inplace=True),
            nn.Linear(25, 10),
       )
         
optimizer = optim.SGD(nn_model.parameters(), lr=1e-3, weight_decay=1e-1)
loss_history, train_history, val_history =\
train_model(nn_model, train_loader, val_loader, loss, optimizer, 10,enable_scheduler=True, scheduler_gamma=0.2)
# Out:
# Average loss: 2.093635, Train accuracy: 0.297666, Val accuracy: 0.388301
# Average loss: 1.882607, Train accuracy: 0.432242, Val accuracy: 0.480855
# Average loss: 1.802916, Train accuracy: 0.485804, Val accuracy: 0.495802
# Average loss: 1.781363, Train accuracy: 0.498089, Val accuracy: 0.508907
# Average loss: 1.765985, Train accuracy: 0.506928, Val accuracy: 0.517439
# Average loss: 1.762325, Train accuracy: 0.507661, Val accuracy: 0.515869
# Average loss: 1.759984, Train accuracy: 0.509743, Val accuracy: 0.514163
# Average loss: 1.759991, Train accuracy: 0.508736, Val accuracy: 0.515733
# Average loss: 1.758202, Train accuracy: 0.510886, Val accuracy: 0.517576
# Average loss: 1.758796, Train accuracy: 0.508958, Val accuracy: 0.515050

# %%
nn_model = nn.Sequential(
            Flattener(),
            nn.Linear(3*32*32, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 50), 
            nn.BatchNorm1d(50),
            nn.ReLU(inplace=True),
            nn.Linear(50, 25), 
            nn.BatchNorm1d(25),
            nn.ReLU(inplace=True),
            nn.Linear(25, 10),
       )
         
optimizer = optim.SGD(nn_model.parameters(), lr=1e-2, weight_decay=1e-1)
loss_history, train_history, val_history =\
train_model(nn_model, train_loader, val_loader, loss, optimizer, 10 ,enable_scheduler=True, scheduler_gamma=0.5)
# Out:
# Average loss: 1.904645, Train accuracy: 0.369587, Val accuracy: 0.459081
# Average loss: 1.721118, Train accuracy: 0.480668, Val accuracy: 0.509044
# Average loss: 1.630776, Train accuracy: 0.528700, Val accuracy: 0.520920
# Average loss: 1.597914, Train accuracy: 0.536925, Val accuracy: 0.536687
# Average loss: 1.529742, Train accuracy: 0.567826, Val accuracy: 0.569176
# Average loss: 1.510812, Train accuracy: 0.571546, Val accuracy: 0.573271
# Average loss: 1.461908, Train accuracy: 0.593147, Val accuracy: 0.601529
# Average loss: 1.452970, Train accuracy: 0.591885, Val accuracy: 0.568698
# Average loss: 1.417675, Train accuracy: 0.607549, Val accuracy: 0.607399
# Average loss: 1.409637, Train accuracy: 0.608948, Val accuracy: 0.615726

# %%
# add a hidden layer with 50 neurons

nn_model = nn.Sequential(
            Flattener(),
            nn.Linear(3*32*32, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 50),
            nn.BatchNorm1d(50),
            nn.ReLU(inplace=True),
            nn.Linear(50, 10),
       )

optimizer = optim.SGD(nn_model.parameters(), lr=1e-3, weight_decay=1e-1)
loss_history, train_history, val_history = train_model(nn_model, train_loader, val_loader, loss, optimizer, 10)
# Out:
# Average loss: 2.081584, Train accuracy: 0.300174, Val accuracy: 0.427957
# Average loss: 1.785403, Train accuracy: 0.469269, Val accuracy: 0.512593
# Average loss: 1.642947, Train accuracy: 0.532608, Val accuracy: 0.562214
# Average loss: 1.553176, Train accuracy: 0.572399, Val accuracy: 0.603713
# Average loss: 1.494398, Train accuracy: 0.594188, Val accuracy: 0.620299
# Average loss: 1.453312, Train accuracy: 0.610279, Val accuracy: 0.628831
# Average loss: 1.421591, Train accuracy: 0.626216, Val accuracy: 0.640298
# Average loss: 1.397271, Train accuracy: 0.636812, Val accuracy: 0.643301
# Average loss: 1.373955, Train accuracy: 0.647459, Val accuracy: 0.633472
# Average loss: 1.357283, Train accuracy: 0.658175, Val accuracy: 0.667053

# %%
# use Adam optimizer

nn_model = nn.Sequential(
            Flattener(),
            nn.Linear(3*32*32, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 50),
            nn.BatchNorm1d(50),
            nn.ReLU(inplace=True),
            nn.Linear(50, 10),
       )

optimizer = optim.Adam(nn_model.parameters(), lr=1e-3)
loss_history, train_history, val_history = train_model(nn_model, train_loader, val_loader, loss, optimizer, 10)
# Out:
# Average loss: 1.371439, Train accuracy: 0.549910, Val accuracy: 0.674903
# Average loss: 0.938258, Train accuracy: 0.703341, Val accuracy: 0.737015
# Average loss: 0.815871, Train accuracy: 0.742569, Val accuracy: 0.771688
# Average loss: 0.734349, Train accuracy: 0.769921, Val accuracy: 0.784247
# Average loss: 0.682910, Train accuracy: 0.785039, Val accuracy: 0.793802
# Average loss: 0.650075, Train accuracy: 0.794338, Val accuracy: 0.788479
# Average loss: 0.622075, Train accuracy: 0.802409, Val accuracy: 0.804518
# Average loss: 0.592256, Train accuracy: 0.812135, Val accuracy: 0.811685
# Average loss: 0.569038, Train accuracy: 0.821366, Val accuracy: 0.814484
# Average loss: 0.548700, Train accuracy: 0.825666, Val accuracy: 0.818784

# %%
nn_model = nn.Sequential(
            Flattener(),
            nn.Linear(3*32*32, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 100), 
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 10),
       )

optimizer = optim.Adam(nn_model.parameters(), lr=1e-3)
loss_history, train_history, val_history = train_model(nn_model, train_loader, val_loader, loss, optimizer, 5)
# Out:
# Average loss: 1.318688, Train accuracy: 0.576067, Val accuracy: 0.712511
# Average loss: 0.931468, Train accuracy: 0.707283, Val accuracy: 0.751826
# Average loss: 0.803774, Train accuracy: 0.748865, Val accuracy: 0.759266
# Average loss: 0.728441, Train accuracy: 0.773095, Val accuracy: 0.780493
# Average loss: 0.684029, Train accuracy: 0.786507, Val accuracy: 0.791755

# %%
nn_model = nn.Sequential(
            Flattener(),
            nn.Linear(3*32*32, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 100), 
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 10),
       )

optimizer = optim.Adam(nn_model.parameters(), lr=5e-3)
loss_history, train_history, val_history = train_model(nn_model, train_loader, val_loader, loss, optimizer, 5)
# Out:
# Average loss: 1.340111, Train accuracy: 0.555404, Val accuracy: 0.682411
# Average loss: 0.938967, Train accuracy: 0.702198, Val accuracy: 0.736059
# Average loss: 0.816843, Train accuracy: 0.744412, Val accuracy: 0.764658
# Average loss: 0.746063, Train accuracy: 0.768027, Val accuracy: 0.764931
# Average loss: 0.692563, Train accuracy: 0.783145, Val accuracy: 0.803290

# %%
nn_model = nn.Sequential(
            Flattener(),
            nn.Linear(3*32*32, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 100), 
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 10),
       )

         
optimizer = optim.Adam(nn_model.parameters(), lr=1e-2)
loss_history, train_history, val_history =\
train_model(nn_model, train_loader, val_loader, loss, optimizer, 5 ,enable_scheduler=True, scheduler_gamma=0.5)
# Out:
# Average loss: 1.347384, Train accuracy: 0.556155, Val accuracy: 0.686096
# Average loss: 0.940819, Train accuracy: 0.705474, Val accuracy: 0.733124
# Average loss: 0.754407, Train accuracy: 0.766372, Val accuracy: 0.778104
# Average loss: 0.701670, Train accuracy: 0.782241, Val accuracy: 0.794144
# Average loss: 0.619362, Train accuracy: 0.807306, Val accuracy: 0.806634

# %%
nn_model = nn.Sequential(
            Flattener(),
            nn.Linear(3*32*32, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 100), 
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 10),
       )

         
optimizer = optim.Adam(nn_model.parameters(), lr=5e-3)
loss_history, train_history, val_history =\
train_model(nn_model, train_loader, val_loader, loss, optimizer, 5 ,enable_scheduler=True, scheduler_gamma=0.8)
# Out:
# Average loss: 1.379866, Train accuracy: 0.539552, Val accuracy: 0.695720
# Average loss: 0.941111, Train accuracy: 0.702966, Val accuracy: 0.755102
# Average loss: 0.784944, Train accuracy: 0.756049, Val accuracy: 0.773736
# Average loss: 0.719575, Train accuracy: 0.775654, Val accuracy: 0.786090
# Average loss: 0.657563, Train accuracy: 0.793554, Val accuracy: 0.801447

# %%
nn_model = nn.Sequential(
            Flattener(),
            nn.Linear(3*32*32, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 100), 
            nn.BatchNorm1d(100),
            nn.ReLU(inplace=True),
            nn.Linear(100, 10),
       )

         
optimizer = optim.Adam(nn_model.parameters(), lr=1e-3)
loss_history, train_history, val_history =\
train_model(nn_model, train_loader, val_loader, loss, optimizer, 5 ,enable_scheduler=True, scheduler_gamma=0.8)
# Out:
# Average loss: 1.326410, Train accuracy: 0.569396, Val accuracy: 0.704116
# Average loss: 0.919226, Train accuracy: 0.710013, Val accuracy: 0.723227
# Average loss: 0.782511, Train accuracy: 0.755076, Val accuracy: 0.777763
# Average loss: 0.719594, Train accuracy: 0.777139, Val accuracy: 0.789571
# Average loss: 0.656108, Train accuracy: 0.795686, Val accuracy: 0.804723

# %%
# Как всегда, в конце проверяем на test set
test_loader = torch.utils.data.DataLoader(data_test, batch_size=batch_size)
test_accuracy = compute_accuracy(nn_model, test_loader)
print("Test accuracy: %2.4f" % test_accuracy)
# Out:
# Test accuracy: 0.8047

# %% [markdown]
# Финальный скор > 0.8, ключевым фактором для достижения высокой точности было применение алгоритма Adam вместо SGD.
